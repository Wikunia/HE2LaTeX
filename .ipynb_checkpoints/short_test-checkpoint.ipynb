# %%
import os
from Latex.Latex import Latex
import numpy as np
from os import listdir
from skimage import io
import matplotlib.pyplot as plt
from IPython.display import display, Math
import tensorflow as tf
from Seq2SeqModel.Seq2SeqModel import Seq2SeqModel

import tensorflow.contrib.legacy_seq2seq as seq2seq
# Out:
# /usr/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
train_images = np.load("train_images.npy")
train_labels = np.load("train_labels.npy")

# %%
mean_train = np.mean(train_images, axis=0)
std_train = np.std(train_images, axis=0)

# %%
model = Latex("model", mean_train, std_train, plotting=True)
seqModel = Seq2SeqModel()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-22ed15dd688e> in <module>()
#       1 model = Latex("model", mean_train, std_train, plotting=True)
# ----> 2 seqModel = Seq2SeqModel()
#       3 seq_sess = tf.Session()
#
# ~/Documents/Heidelberg/OR/project/Seq2SeqModel/Seq2SeqModel.py in __init__(self)
#      35         with tf.variable_scope("encoding") as encoding_scope:
#      36             lstm_enc = tf.contrib.rnn.BasicLSTMCell(nodes)
# ---> 37             _, last_state = tf.nn.dynamic_rnn(lstm_enc, inputs=inputs, dtype=tf.float32)
#      38
#      39         with tf.variable_scope("decoding") as decoding_scope:
#
# /usr/lib/python3.6/site-packages/tensorflow/python/ops/rnn.py in dynamic_rnn(cell, inputs, sequence_length, initial_state, dtype, parallel_iterations, swap_memory, time_major, scope)
#     630         swap_memory=swap_memory,
# ...

# %%
seq_sess = tf.Session()

# %%
no = 1
cp = 0
files = listdir("formulas/test/fractions")
for i in range(0,0+no):
    formula = io.imread("formulas/test/fractions/"+files[i])
    correct = model.filename2formula(files[i])
    latex = model.predict(formula)
    seqModel.restore(seq_sess)
    seq = seqModel.predict_single(seq_sess, X_test[0])
    print("Seq: ", seq)
    
    
print("Accuracy: %.1f %%" % ((cp/no)*100))
# Out:
# Start threshold:
# Start bounding boxes:
# Final bounding boxes:
# Accuracy: 0.0 %
